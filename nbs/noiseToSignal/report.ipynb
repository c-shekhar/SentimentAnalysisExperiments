# %%
import matplotlib.pyplot as plt

# %%
correct_rates = [49.774, 59.785, 69.899, 79.682]
f1_scores = [0.0, 88.30, 92.95, 94.07]
accuracies = [50.76, 87.38, 92.86, 94.14]

# %%
plt.plot(correct_rates, f1_scores, 'bo--',)
plt.xlabel('correct rate')
plt.ylabel('f1-score')
# Out:
# Text(0, 0.5, 'f1-score')

# %%
plt.plot(correct_rates, accuracies, 'bo--')
plt.xlabel('correct rate')
plt.ylabel('accuracy')
# Out:
# Text(0, 0.5, 'accuracy')
